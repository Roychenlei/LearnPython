# %%
import pymongo
import json
import pandas as pd
from pymongo import MongoClient
client = MongoClient(host='mongodb1.dev.zippia.com')
client1 = MongoClient(host='localhost')
salary_by_location = client['zippia']['salary_by_location']
salary_by_location_old = client1['zippia']['salary_by_location']
salary_new = client['zippia']['salary']
salary_old = client1['zippia']['sly_lo']

# %%
a= list(salary_new.find({'titleDisplay':'Computer Systems Administrator','isOutlier':0},{'caseId':1}))
for r in a:
    r['_id'] = None
# with open('ComputerSystemsAdminstrator_new.json','w')as w:
#     json.dump(a,w)
# df = pd.read_json('ComputerSystemsAdminstrator.json')
# print df.sort_values('caseId',ascending=False)

b= list(salary_old.find({'titleDisplay':'Computer Systems Administrator','isOutlier':0},{'caseId':1}))
for r in a:
    r['_id'] = None
# with open('ComputerSystemsAdminstrator_old.json','w')as w:
#     json.dump(b,w)
# df = pd.read_json('ComputerSystemsAdminstrator_old.json')
# print df.sort_values('caseId',ascending=False)

print b
# Out:
# [{u'_id': ObjectId('59e0af49b7b66c6b0744b911'), u'caseId': u'I-08182-4370895'}, {u'_id': ObjectId('59e0ad10b7b66c6b07436879'), u'caseId': u'I-08094-4217011'}, {u'_id': ObjectId('59e0b621b7b66c6b074a157d'), u'caseId': u'I-09063-4719999'}, {u'_id': ObjectId('59e0ad10b7b66c6b07436894'), u'caseId': u'I-08224-4436913'}, {u'_id': ObjectId('59e0ad10b7b66c6b074368a4'), u'caseId': u'I-08224-4437881'}, {u'_id': ObjectId('59e0ad10b7b66c6b0743680d'), u'caseId': u'I-08018-3815657'}, {u'_id': ObjectId('59e0ad10b7b66c6b074368a2'), u'caseId': u'I-08224-4437379'}, {u'_id': ObjectId('59e0b498b7b66c6b0749277e'), u'caseId': u'I-09082-4808503'}, {u'_id': ObjectId('59e0b498b7b66c6b0749278a'), u'caseId': u'I-09084-4826031'}, {u'_id': ObjectId('59e0b498b7b66c6b0749278b'), u'caseId': u'I-09084-4826051'}, {u'_id': ObjectId('59e0af49b7b66c6b0744ba4d'), u'caseId': u'I-08108-4250991'}, {u'_id': ObjectId('59e0af49b7b66c6b0744ba83'), u'caseId': u'I-08179-4366679'}, {u'_id': ObjectId('59e0af49b7b66c6b0744ba82'), u'caseId': u'I-08179-4366659'}, {u'_id': ObjectId('59e0a22cb7b66c6b073b277c'), u'caseId': u'A-11287-11871'}, {u'_id': ObjectId('59e0a22cb7b66c6b073b277d'), u'caseId': u'A-11350-24848'}, {u'_id': ObjectId('59e0ad10b7b66c6b07436848'), u'caseId': u'I-08088-4152955'}, {u'_id': ObjectId('59e0af58b7b66c6b0744c1de'), u'caseId': u'I-07291-3709447'}, {u'_id': ObjectId('59e0af49b7b66c6b0744b9da'), u'caseId': u'I-08079-4034425'}, {u'_id': ObjectId('59e0ad10b7b66c6b07436834'), u'caseId': u'I-08084-4091791'}, {u'_id': ObjectId('59e0ad10b7b66c6b0743684c'), u'caseId': u'I-08088-4158651'}, {u'_id': ObjectId('59e0af4fb7b66c6b0744bf55'), u'caseId': u'I-08260-4487565'}, {u'_id': ObjectId('59e0af4fb7b66c6b0744bf56'), u'caseId': u'I-08260-4488025'}, {u'_id': ObjectId('59e0b627b7b66c6b074a1a4d'), u'caseId': u'I-09117-4934543'}, {u'_id': ObjectId('59e0b627b7b66c6b074a1a08'), u'caseId': u'I-09075-4769471'}, {u'_id': ObjectId('59e0b498b7b66c6b074927b1'), u'caseId': u'I-09119-4941487'}, {u'_id': ObjectId('59e0b627b7b66c6b074a1baa'), u'caseId': u'I-09091-4876589'}, {u'_id': ObjectId('59e0af40b7b66c6b0744b11c'), u'caseId': u'I-08084-4094671'}, {u'_id': ObjectId('59e0af40b7b66c6b0744b11d'), u'caseId': u'I-08084-4094713'}, {u'_id': ObjectId('59e0af40b7b66c6b0744b113'), u'caseId': u'I-08073-3979837'}, {u'_id': ObjectId('59e0af40b7b66c6b0744b114'), u'caseId': u'I-08073-3979915'}, {u'_id': ObjectId('59e0af40b7b66c6b0744b115'), u'caseId': u'I-08073-3980055'}, {u'_id': ObjectId('59e0af40b7b66c6b0744b116'), u'caseId': u'I-08073-3980359'}, {u'_id': ObjectId('59e0af40b7b66c6b0744b117'), u'caseId': u'I-08073-3980443'}, {u'_id': ObjectId('59e0af40b7b66c6b0744b118'), u'caseId': u'I-08074-3983845'}, {u'_id': ObjectId('59e0af40b7b66c6b0744b119'), u'caseId': u'I-08074-3983939'}, {u'_id': ObjectId('59e0af49b7b66c6b0744b8e6'), u'caseId': u'I-08064-3918261'}, {u'_id': ObjectId('59e0af4fb7b66c6b0744bf3a'), u'caseId': u'I-08094-4220431'}, {u'_id': ObjectId('59e0b627b7b66c6b074a19ef'), u'caseId': u'I-09050-4686553'}, {u'_id': ObjectId('59e0b627b7b66c6b074a19ed'), u'caseId': u'I-09048-4678671'}, {u'_id': ObjectId('59e0b627b7b66c6b074a1d78'), u'caseId': u'I-08294-4533375'}, {u'_id': ObjectId('59e0ad02b7b66c6b07435d96'), u'caseId': u'I-08192-4387213'}, {u'_id': ObjectId('59e0ad02b7b66c6b07435d98'), u'caseId': u'I-08192-4387203'}, {u'_id': ObjectId('59e0ad02b7b66c6b07435d97'), u'caseId': u'I-08192-4387193'}, {u'_id': ObjectId('59e0b498b7b66c6b074927b5'), u'caseId': u'I-09139-4976401'}, {u'_id': ObjectId('59e0b4c6b7b66c6b07494691'), u'caseId': u'I-09167-5020217'}, {u'_id': ObjectId('59e0ad10b7b66c6b0743687b'), u'caseId': u'I-08094-4222169'}, {u'_id': ObjectId('59e0af5cb7b66c6b0744c752'), u'caseId': u'I-08074-3984121'}, {u'_id': ObjectId('59e0af4fb7b66c6b0744bf21'), u'caseId': u'I-08083-4079127'}, {u'_id': ObjectId('59e0af40b7b66c6b0744b14a'), u'caseId': u'I-08068-3944733'}, {u'_id': ObjectId('59e0af49b7b66c6b0744ba50'), u'caseId': u'I-08126-4278773'}, {u'_id': ObjectId('59e0b627b7b66c6b074a19cc'), u'case ...

# %%
i = 0
for old in b:
    for new in a:
        i += 1
        if old['caseId'] == new['caseId']:
            break
        else:
            print new['caseId']

# %%
with open('ComputerSystemsAdminstrator.json','w')as w:
    json.dump(a,w)

# %%
computer_new = list(salary_new.find({'titleDisplay':'Computer Systems Administrator','isOutlier':0},{'caseId':1}))
for r in computer_new:
    r['_id'] = None
with open('ComputerSystemsAdminstrator_new.json','w')as w:
    json.dump(a,w)
# df = pd.read_json('ComputerSystemsAdminstrator.json')

# %%
computer_old = list(salary_old.find({'titleDisplay':'Computer Systems Administrator','isOutlier':0},{'caseId':1}))


for r in computer_old:
    r['_id'] = None

with open('ComputerSystemsAdminstrator_old.json','w')as w:
    json.dump(computer_old,w)
# df = pd.read_json('ComputerSystemsAdminstrator_old.json')
# print df.sort_values('caseId',ascending=False)

# %%
x = set([x['caseId']for x in computer_new]).difference (set([x['caseId']for x in computer_old]))
x = list(x)
with open('ComputerSystemsAdminstrator.json','w') as w:
    json.dump(x,w)

# %%
import pymongo
import json
import pandas as pd
from pymongo import MongoClient
client = MongoClient(host='mongodb1.dev.zippia.com')
client1 = MongoClient(host='localhost')
salary_by_location = client['zippia']['salary_by_location']
salary_by_location_old = client1['zippia']['salary_by_location']
salary_new = client['zippia']['salary']
salary_old = client1['zippia']['sly_lo']

computer_new = list(salary_new.find({'titleDisplay':'Computer Systems Administrator','isOutlier':0},{'caseId':1}))
print len(computer_new)
for r in computer_new:
    r['_id'] = None
with open('ComputerSystemsAdminstrator_new.json','w')as w:
    json.dump(a,w)


computer_old = list(salary_old.find({'titleDisplay':'Computer Systems Administrator','isOutlier':0},{'caseId':1}))
print len(computer_old)
for r in computer_old:
    r['_id'] = None
with open('ComputerSystemsAdminstrator_old.json','w')as w:
    json.dump(computer_old,w)


x = set([x['caseId']for x in computer_new]).difference (set([x['caseId']for x in computer_old]))
x = list(x)
print len(x)
with open('/home/chenlei/ENV/data/ComputerSystemsAdminstrator.json','w') as w:
    json.dump(x,w)
# Out:
# 14530
# 13720
# 778

# %%
computer_new = list(salary_new.find({'titleDisplay':'Accountant','isOutlier':0},{'caseId':1}))
print len(computer_new)
for r in computer_new:
    r['_id'] = None
with open('Accountant_new.json','w')as w:
    json.dump(a,w)


computer_old = list(salary_old.find({'titleDisplay':'Accountant','isOutlier':0},{'caseId':1}))
print len(computer_old)
for r in computer_old:
    r['_id'] = None
with open('Accountant_old.json','w')as w:
    json.dump(computer_old,w)


x = set([x['caseId']for x in computer_new]).difference (set([x['caseId']for x in computer_old]))
x = list(x)
print len(x)
with open('/home/chenlei/ENV/data/Accountant.json','w') as w:
    json.dump(x,w)
# Out:
# 33198
# 32496
# 663

# %%
computer_new = list(salary_new.find({'titleDisplay':'Graphic Designer','isOutlier':0},{'caseId':1}))
print len(computer_new)
for r in computer_new:
    r['_id'] = None
with open('Graphic Designer_new.json','w')as w:
    json.dump(a,w)


computer_old = list(salary_old.find({'titleDisplay':'Graphic Designer','isOutlier':0},{'caseId':1}))
print len(computer_old)
for r in computer_old:
    r['_id'] = None
with open('Graphic Designer_old.json','w')as w:
    json.dump(computer_old,w)


x = set([x['caseId']for x in computer_new]).difference (set([x['caseId']for x in computer_old]))
x = list(x)
print len(x)
with open('/home/chenlei/ENV/data/GraphicDesigner.json','w') as w:
    json.dump(x,w)
# Out:
# 12228
# 11907
# 306

# %%
computer_new = list(salary_new.find({'titleDisplay':'Investment Analyst','isOutlier':0},{'caseId':1}))
print len(computer_new)
for r in computer_new:
    r['_id'] = None
with open('InvestmentAnalyst.json','w')as w:
    json.dump(a,w)


computer_old = list(salary_old.find({'titleDisplay':'Investment Analyst','isOutlier':0},{'caseId':1}))
print len(computer_old)
for r in computer_old:
    r['_id'] = None
with open('InvestmentAnalyst.json','w')as w:
    json.dump(computer_old,w)


x = set([x['caseId']for x in computer_new]).difference (set([x['caseId']for x in computer_old]))
x = list(x)
print len(x)
with open('/home/chenlei/ENV/data/InvestmentAnalyst.json','w') as w:
    json.dump(x,w)
# Out:
# 2747
# 2659
# 67

# %%
computer_new = list(salary_new.find({'titleDisplay':'Data Analyst','isOutlier':0},{'caseId':1}))
print len(computer_new)
for r in computer_new:
    r['_id'] = None
with open('Data Analyst.json','w')as w:
    json.dump(a,w)


computer_old = list(salary_old.find({'titleDisplay':'Data Analyst','isOutlier':0},{'caseId':1}))
print len(computer_old)
for r in computer_old:
    r['_id'] = None
with open('Data Analyst_old.json','w')as w:
    json.dump(computer_old,w)


x = set([x['caseId']for x in computer_new]).difference (set([x['caseId']for x in computer_old]))
x = list(x)
print len(x)
with open('/home/chenlei/ENV/data/DataAnalyst.json','w') as w:
    json.dump(x,w)
# Out:
# 12519
# 11768
# 627

# %%
import json
a= list(salary_by_location.aggregate([
                                {'$group':{'_id':'$loc_type','avgAmount':{'$avg':'$salary'}}},
                               {'$project':{'loc_type':1,'avgAmount':1}}
                                  ]))

with open('City_by_salary.json', 'w') as w:
    json.dump(a,w)
import pandas as pd
df = pd.read_json('City_by_salary.json')
print df.sort_values('avgAmount',ascending=False)
# Out:
#           _id     avgAmount
# 1    Top City  74696.585828
# 3       State  66629.563512
# 2      Nation  64687.475268
# 0  Metro Area  56187.598869

# %%
import json
a= list(salary_by_location_new.aggregate([
                                {'$group':{'_id':'$loc_type','avgAmount':{'$avg':'$salary'}}},
                               {'$project':{'loc_type':1,'avgAmount':1}}
                                  ]))

with open('City_by_salary.json', 'w') as w:
    json.dump(a,w)
import pandas as pd
df = pd.read_json('City_by_salary.json')
print df.sort_values('avgAmount',ascending=False)
# Out:
#           _id     avgAmount
# 1    Top City  74766.604025
# 3       State  66643.562638
# 2      Nation  64727.192233
# 0  Metro Area  56187.598869

# %%
import json
a= list(salary_by_location_new.aggregate([{'$match':{'loc_name':'New York__NY'}},
                                {'$group':{'_id':'$loc_name','avgAmount':{'$avg':'$salary'}}},
                               {'$project':{'loc_name':1,'avgAmount':1}}
                                  ]))

with open('CA_salary.json', 'w') as w:
    json.dump(a,w)
import pandas as pd
df = pd.read_json('CA_salary.json')
print df.sort_values('avgAmount',ascending=False)
# Out:
#             _id     avgAmount
# 0  New York__NY  80797.550866

# %%
import json
a= list(salary_by_location.aggregate([{'$match':{'loc_name':'New York__NY'}},
                                {'$group':{'_id':'$loc_name','avgAmount':{'$avg':'$salary'}}},
                               {'$project':{'loc_name':1,'avgAmount':1}}
                                  ]))
print a
with open('CA_salary1.json', 'w') as w:
    json.dump(a,w)
import pandas as pd
df = pd.read_json('CA_salary1.json')
print df.sort_values('avgAmount',ascending=False)
# Out:
# [{u'_id': u'New York__NY', u'avgAmount': 80807.61439944137}]
#             _id     avgAmount
# 0  New York__NY  80807.614399

# %%
a= list(salary_by_location.aggregate(
                                [
                                     {
                                       '$match':{
                                           'loc_name':'CA'
                                       } 
                                    },
                                    {'$group':
                                        {
                                         '_id':"$loc_name",
                                         'count':{'$sum':1}
                                        }
                                    }
                                ]
                                )
       )
print a
with open('count.json', 'w') as w:
    json.dump(a,w)
import pandas as pd
df = pd.read_json('count.json')
print df.sort_values('count',ascending=False)
# Out:
# [{u'count': 9014, u'_id': u'CA'}]
#   _id  count
# 0  CA   9014

# %%
a= list(salary_by_location_new.aggregate([
                                    {
                                       '$match':{
                                           'loc_name':'CA'
                                       } 
                                    },
                                    {
                                        '$group':
                                        {
                                         '_id':"$loc_name",
                                         'count':{'$sum':1}
                                        }
                                    }
                                ]
                                )
       )
print a
with open('count.json', 'w') as w:
    json.dump(a,w)
import pandas as pd
df = pd.read_json('count.json')
print df.sort_values('count',ascending=False)
# Out:
# [{u'count': 9012, u'_id': u'CA'}]
#   _id  count
# 0  CA   9012

# %%
a= list(salary_by_location_new.aggregate([
                                    {
                                       '$match':{
                                           'value':'Computer Systems Administrator'
                                       } 
                                    },
                                    {
                                        '$group':
                                        {
                                         '_id':"$salary",
                                         'count':{'$sum':1}
                                        }
                                    }
                                ]
                                )
       )
with open('count.json', 'w') as w:
    json.dump(a,w)
import pandas as pd
df = pd.read_json('count.json')
print df.sort_values('count',ascending=False)
# Out:
#             _id  count
# 228   60000.000     32
# 192   70000.000      7
# 233   66000.000      6
# 168   80000.000      5
# 200   75000.000      4
# 217   60700.000      4
# 173   62600.000      4
# 61    63000.000      4
# 211   61000.000      4
# 135   64300.000      3
# 212   63500.000      3
# 156   60600.000      3
# 20    68000.000      3
# 215   61100.000      2
# 85    69000.000      2
# 188   60100.000      2
# 172   64501.000      2
# 143   59000.000      2
# 210   66784.000      2
# 147   62000.000      2
# 163   55000.000      2
# 193   61800.000      2
# 155   83000.000      2
# 218   68453.000      2
# 59    67000.000      2
# 220   66500.000      2
# 78    54500.000      2
# 124   68557.000      2
# 177   65000.000      2
# 178   73000.000      2
# ..          ...    ...
# 122   54746.000      1
# 96    66600.000      1
# 95    61818.000      1
# 94    67250.000      1
# 76    56781.000      1
# 65    61169.000      1
# 66    50000.000      1
# 67    90000.000      1
# 68    62787.000      1
# 69    55602.500      1
# 70    72150.500      1
# 71    82963.715      1
# 72    57100.000      1
# 73    69451.000      1
# 74    61090.000      1
# 75    72000.000      1
# 77    73500.000      1
# 93    68798.500      1
# 79    55806.000      1
# 80    78374.400      1
# 81    69100.000      1
# 82    75283.000      1
# 84    52000.000      1
# 86    53000.000      1
# 87   100110.000      1
# 88    76316.000      1
# 89    51300.000      1
# 91    78202.500      1
# 92    60867.500      1
# 240   79500.000      1
#
# [241 rows x 2 columns]

# %%
a= list(salary_by_location.aggregate([
                                    {
                                       '$match':{
                                           'value':'Computer Systems Administrator'
                                       } 
                                    },
                                    {
                                        '$group':
                                        {
                                         '_id':"$salary",
                                         'count':{'$sum':1}
                                        }
                                    }
                                ]
                                )
       )
with open('count.json', 'w') as w:
    json.dump(a,w)
import pandas as pd
df = pd.read_json('count.json')
print df.sort_values('count',ascending=False)
# Out:
#               _id  count
# 354  60000.000000     32
# 375  61000.000000      8
# 360  70000.000000      8
# 365  80000.000000      7
# 197  65000.000000      6
# 316  63000.000000      6
# 173  66000.000000      5
# 310  68000.000000      4
# 154  62500.000000      4
# 387  62600.000000      4
# 343  67000.000000      4
# 321  63500.000000      4
# 363  61800.000000      3
# 78   66435.200000      3
# 296  90000.000000      3
# 391  64501.000000      3
# 198  73000.000000      3
# 195  60600.000000      3
# 254  64300.000000      3
# 155  67500.000000      2
# 280  52155.212458      2
# 211  47826.092395      2
# 54   75000.000000      2
# 381  53448.070000      2
# 248  60803.000000      2
# 69   60700.000000      2
# 361  69700.000000      2
# 253  66466.340000      2
# 257  56634.704150      2
# 348  61200.000000      2
# ..            ...    ...
# 115  70283.200000      1
# 114  63269.000000      1
# 113  54537.415637      1
# 112  61003.000000      1
# 137  55305.500000      1
# 138  68294.500000      1
# 139  66594.500000      1
# 140  62200.000000      1
# 163  65520.000000      1
# 162  65300.000000      1
# 161  62276.080000      1
# 160  45078.500000      1
# 159  62610.000000      1
# 158  72030.000000      1
# 157  69450.000000      1
# 156  58436.000000      1
# 153  52000.000000      1
# 152  64900.000000      1
# 151  60129.000000      1
# 150  77800.000000      1
# 149  81962.500000      1
# 148  64875.000000      1
# 147  56698.018521      1
# 146  62842.500000      1
# 145  59380.964958      1
# 144  56000.000000      1
# 143  51996.926533      1
# 142  67300.000000      1
# 141  71651.200000      1
# 216  73775.450000      1
#
# [432 rows x 2 columns]

# %%
import json
a= list(salary_by_location.aggregate([{'$match':{'value':'Supply Chain Development Manager'}},
                                           {'$project':{'loc_name':1,'salary':1,'total_salary_records':1}}
                                  ]))
for x in a:
    x['_id'] = None
with open('title.json', 'w') as w:
    json.dump(a,w)
import pandas as pd
df = pd.read_json('title.json')
print df.sort_values('salary',ascending=False)
# Out:
#    _id loc_name  salary  total_salary_records
# 0  NaN       VA  121630                     1
# 1  NaN       TX  111800                     1
# 3  NaN       PA  108610                     2
# 7  NaN       CT  108250                     2
# 5  NaN       GA  104650                     1
# 2  NaN       MO   98360                     3
# 6  NaN       FL   96850                     3
# 4  NaN       IL   90560                     8
# 8  NaN   Nation   65000                    21

# %%
import json
a= list(salary_by_location.aggregate([{'$match':{'value':'Survey Researcher','loc_name':'New York__NY'}},
                                           {'$project':{'loc_name':1,'salary':1,'total_salary_records':1}}
                                  ]))
for x in a:
    x['_id'] = None
with open('title.json', 'w') as w:
    json.dump(a,w)
import pandas as pd
df = pd.read_json('title.json')
print df.sort_values('salary',ascending=False)

a= list(salary_by_location_new.aggregate([{'$match':{'value':'Survey Researcher','loc_name':'New York__NY'}},
                                           {'$project':{'loc_name':1,'salary':1,'total_salary_records':1}}
                                  ]))
for x in a:
    x['_id'] = None
with open('title.json', 'w') as w:
    json.dump(a,w)
import pandas as pd
df = pd.read_json('title.json')
print df.sort_values('salary',ascending=False)
# Out:
#    _id      loc_name  salary  total_salary_records
# 0  NaN  New York__NY   42330                    44
#    _id      loc_name  salary  total_salary_records
# 0  NaN  New York__NY   43410                    43

# %%
a =list(salary_by_location_new.find({'value':'Computer Systems Administrator'}))
print a
with open('title.json', 'w') as w:
    json.dump(a,w)
import pandas as pd
df = pd.read_json('title.json')
print df.sort_values('avgAmount',ascending=False)
# Out:
# [{u'salary': 64958.0, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'WA', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fbd'), u'total_salary_records': 424}, {u'salary': 60000.0, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'DE', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fbe'), u'total_salary_records': 117}, {u'salary': 68453.0, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'DC', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fbf'), u'total_salary_records': 150}, {u'salary': 60700.0, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'WI', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fc0'), u'total_salary_records': 86}, {u'salary': 45699.28432402812, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'WV', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fc1'), u'total_salary_records': 8}, {u'salary': 56760.054863885176, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'HI', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fc2'), u'total_salary_records': 19}, {u'salary': 60000.0, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'FL', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fc3'), u'total_salary_records': 427}, {u'salary': 68600.0, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'NH', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fc4'), u'total_salary_records': 81}, {u'salary': 66000.0, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'NJ', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fc5'), u'total_salary_records': 1790}, {u'salary': 56354.22803112784, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'NM', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fc6'), u'total_salary_records': 13}, {u'salary': 63944.0, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'TX', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fc7'), u'total_salary_records': 1714}, {u'salary': 43555.0, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'LA', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fc8'), u'total_salary_records': 25}, {u'salary': 66500.0, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'NC', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fc9'), u'total_salary_records': 303}, {u'salary': 51325.15826048779, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'ND', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fca'), u'total_salary_records': 4}, {u'salary': 61000.0, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'NE', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fcb'), u'total_salary_records': 37}, {u'salary': 61000.0, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'TN', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fcc'), u'total_salary_records': 59}, {u'salary': 67535.32, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'NY', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fcd'), u'total_salary_records': 719}, {u'salary': 60700.0, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'PA', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fce'), u'total_salary_records': 325}, {u'salary': 61901.275, u'type': u'Title', u'value': u'Computer Systems Administrator', u'loc_name': u'RI', u'loc_type': u'State', u'_id': ObjectId('5a2a5ef7c4d3ac6629116fcf'), u'total_salary_records': 36}, {u'salary': 68682.0, u'type': u'Title', u'value': u'Computer Systems A ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-ca8575ab1502> in <module>()
#       2 print a
#       3 with open('title.json', 'w') as w:
# ----> 4     json.dump(a,w)
#       5 import pandas as pd
#       6 df = pd.read_json('title.json')
#
# /usr/lib/python2.7/json/__init__.pyc in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     187     # could accelerate with writelines in some versions of Python, at
#     188     # a debuggability cost
# --> 189     for chunk in iterable:
#     190         fp.write(chunk)
#     191
#
# /usr/lib/python2.7/json/encoder.pyc in _iterencode(o, _current_indent_level)
#     429             yield _floatstr(o)
#     430         elif isinstance(o, (list, tuple)):
# --> 431             for chunk in _iterencode_list(o, _current_indent_level):
#     432                 yield chunk
#     433         elif isinstance(o, dict):
#
# /usr/lib/python2.7/json/encoder.pyc in _iterencode_list(lst, _current_indent_level)
#     330                 else:
#     331                     chunks = _iterencode(value, _current_indent_level)
# --> 332                 for chunk in chunks:
#     333                     yield chunk
#     334         if newline_indent is not None:
#
# /usr/lib/python2.7/json/encoder.pyc in _iterencode_dict(dct, _current_indent_level)
#     406                 else:
#     407                     chunks = _iterencode(value, _current_indent_level)
# --> 408                 for chunk in chunks:
#     409                     yield chunk
#     410         if newline_indent is not None:
#
# /usr/lib/python2.7/json/encoder.pyc in _iterencode(o, _current_indent_level)
#     440                     raise ValueError("Circular reference detected")
#     441                 markers[markerid] = o
# --> 442             o = _default(o)
#     443             for chunk in _iterencode(o, _current_indent_level):
#     444                 yield chunk
#
# /usr/lib/python2.7/json/encoder.pyc in default(self, o)
#     182
#     183         """
# --> 184         raise TypeError(repr(o) + " is not JSON serializable")
#     185
#     186     def encode(self, o):
#
# TypeError: ObjectId('5a2a5ef7c4d3ac6629116fbd') is not JSON serializable

# %%
import pymongo
from pymongo import MongoClient
client = MongoClient(host='mongodb1.dev.zippia.com')
client1 = MongoClient(host='localhost')
salary_by_location = client['zippia']['salary_by_location']
salary_by_location_old = client1['zippia']['salary_by_location']

# %%
salary_by_location.count({})
salary_by_location_old({})
# Out:
# 712052
# 517087

# %%
a = list(salary_by_location_old.find({'loc_name':{'$in':['CA','WA','MA','NY','FL']},
                                              'value':{'$in':['Accountant','Computer Systems Administrator','Partner',
                                                               'Investment Analyst',
                                                               'Graphic Designer','Data Analyst',"Chief Scientific Officer",
                                                  "Investor"]}},{'salary':1,'total_salary_records':1,'loc_name':1,'value':1}))


for x in a:
    x['_id'] = None
    x['salary'] = int(x['salary'])
with open('title.json', 'w') as w:
    json.dump(a,w)
import pandas as pd
df = pd.read_json('title.json')
print df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f15f78b0c5f7> in <module>()
# ----> 1 a = list(salary_by_location_old.find({'loc_name':{'$in':['CA','WA','MA','NY','FL']},
#       2                                               'value':{'$in':['Accountant','Computer Systems Administrator','Partner',
#       3                                                                'Investment Analyst',
#       4                                                                'Graphic Designer','Data Analyst',"Chief Scientific Officer",
#       5                                                   "Investor"]}},{'salary':1,'total_salary_records':1,'loc_name':1,'value':1}))
#
# NameError: name 'salary_by_location_old' is not defined
